# %%
import requests
import numpy as np
import json
import math
from datetime import datetime, timezone, timedelta
import time
import os

# %%
def list_string(arr):
    return f"{[*map(str,arr)]}".replace("'",'"')

# %%
def get_some_times(route, dt_params=(2018,10,15,0,1,0), hours=20, per_hour=1):
    route_data=[]
    if type(route) != list:
        route = [route]
        
    per_hour=int(per_hour)
    timestamp=int(datetime(*dt_params, tzinfo = timezone(timedelta(hours = -8))).timestamp())*1000 # use PST for tzinfo
    T0 = time.time()
    for i in range(hours*per_hour):
        t0=time.time()
        start_time = timestamp + i*36e5/per_hour
        end_time   = start_time + 36e5/per_hour

        # added direction id to query, needed to obtain stops
        query = f"""{{
          trynState(agency: "muni", startTime: "{start_time}", endTime: "{end_time}", routes: {list_string(route)}) {{
            agency
            startTime
            routes {{
              rid
              stops {{
                sid
                name
                lat
                lon
              }}
              routeStates {{
                vtime
                vehicles {{
                  vid
                  lat
                  lon
                  heading
                  did
                }}
              }}
            }}
          }}
        }}
        """ # Braces need to be doubled for f-string

        query_url = "https://06o8rkohub.execute-api.us-west-2.amazonaws.com/dev/graphql?query="+query
        print('Getting data...',i)
        r = requests.get(query_url)
        print(f'That took {round(time.time()-t0,2)} seconds.')

        data = json.loads(r.text)
        
        try:
            data['data']
        except KeyError as err:
            print(f"Error for time range {startTime}-{endTime}: {err}")
        else:
            if len(data['data']['trynState']['routes']):
                route_data.extend(data['data']['trynState']['routes'])
    r_sort = {}
    print('Final formatting...')
    for x in route_data:
        if x['rid'] not in r_sort.keys():
            r_sort[x['rid']] = {'rid':x['rid'],'routeStates':[],'stops':x['stops']}
        r_sort[x['rid']]['routeStates'].extend(sorted(x['routeStates'], key=lambda rs: int(rs['vtime'])))
    r_sort=list(r_sort.values())
    print('Done')
    print(f'That all took {round(time.time()-T0,2)} seconds.')
    return r_sort

# %% [markdown]
# Testing main scraping function:

# %%
a=get_some_times(['1','14','N','14X','12'],dt_params=(2018,10,15,12),hours=2)
# Out:
# Getting data... 0
# That took 9.77 seconds.
# Getting data... 1
# That took 5.93 seconds.
# Final formatting...
# Done
# That all took 15.81 seconds.

# %% [markdown]
# List of all routes (scraped from https://github.com/trynmaps/opentransit-map/blob/master/src/res/muniRoutes2.json)

# %%
all_routes = ["1","2","3","5","6","7","8","9","10","12","14","18","19","21","22","23","24","25","27","28","29","30","31","33","35","36","37","38","39","41","43","44","45","47","48","49","52","54","55","56","57","66","67","88","90","91","83X","30X","7R","J","N","14R","14X","PH","E","38R","82X","81X","T-OWL","M-OWL","7X","N-OWL","L-OWL","76X","9R","C","38AX","38BX","31BX","1AX","31AX","1BX","K-OWL","F","8AX","8BX","M","L","5R","PM","K/T","NX","28R","BUS"]

# %% [markdown]
# Get 24 hours of data in chunks (more than ~30 routes per call gives an error)

# %%
def get24all(dt_params=(2018,10,15,7)):
    result = []
    t0=time.time()
    # changing the query reduced the number of routes that it could handle before causing errors
    # divide up the routes into 4 sets of 21
    for i in range(4):
        print(f'Chunk {i+1} of 4:')
        result.extend(get_some_times(all_routes[i*21:(i+1)*21],dt_params,hours=24))
    print(f'Whole thing took {round(time.time()-t0,2)} seconds.')
    return result

# %% [markdown]
# Change `dt_params` to whatever date you want. `(year,month,day,hour)`

# %%
allofem=get24all(dt_params=(2018,10,15,0))
# Out:
# Chunk 1 of 4:
# Getting data... 0
# That took 3.26 seconds.
# Getting data... 1
# That took 9.12 seconds.
# Getting data... 2
# That took 13.53 seconds.
# Getting data... 3
# That took 3.93 seconds.
# Getting data... 4
# That took 3.95 seconds.
# Getting data... 5
# That took 6.75 seconds.
# Getting data... 6
# That took 6.95 seconds.
# Getting data... 7
# That took 7.57 seconds.
# Getting data... 8
# That took 6.15 seconds.
# Getting data... 9
# That took 7.62 seconds.
# Getting data... 10
# That took 7.35 seconds.
# Getting data... 11
# That took 7.44 seconds.
# Getting data... 12
# That took 5.76 seconds.
# Getting data... 13
# That took 7.37 seconds.
# Getting data... 14
# That took 26.8 seconds.
# Getting data... 15
# That took 10.94 seconds.
# Getting data... 16
# That took 7.85 seconds.
# Getting data... 17
# That took 8.01 seconds.
# Getting data... 18
# That took 7.98 seconds.
# Getting data... 19
# That took 6.75 seconds.
# Getting data... 20
# That took 10.97 seconds.
# Getting data... 21
# That took 10.42 seconds.
# Getting data... 22
# That took 5.8 seconds.
# Getting data... 23
# That took 10.06 seconds.
# Final formatting...
# Done
# That all took 406.03 seconds.
# Chunk 2 of 4:
# Getting data... 0
# That took 4.87 seconds.
# Getting data... 1
# That took 4.05 seconds.
# Getting data... 2
# That took 3.95 seconds.
# Getting data... 3
# That took 3.99 seconds.
# Getting data... 4
# That took 4.46 seconds.
# Getting data... 5
# That took 5.48 seconds.
# Getting data... 6
# That took 6.27 seconds.
# Getting data... 7
# That took 7.22 seconds.
# Getting data... 8
# That took 7.43 seconds.
# Getting data... 9
# That took 7.42 seconds.
# Getting data... 10
# That took 7.01 seconds.
# Getting data... 11
# That took 7.03 seconds.
# Getting data... 12
# That took 6.89 seconds.
# Getting data... 13
# That took 7.46 seconds.
# Getting data... 14
# That took 7.01 seconds.
# Getting data... 15
# That took 7.29 seconds.
# Getting data... 16
# That took 7.38 seconds.
# Getting data... 17
# That took 7.83 seconds.
# Getting data... 18
# That took 11.61 seconds.
# Getting data... 19
# That took 5.92 seconds.
# Getting data... 20
# That took 6.16 seconds.
# Getting data... 21
# That took 5.52 seconds.
# Getting data... 22
# That took 14.85 seconds.
# Getting data... 23
# That took 5.21 seconds.
# Final formatting...
# Done
# That all took 169.36 seconds.
# Chunk 3 of 4:
# Getting data... 0
# That took 4.32 seconds.
# Getting data... 1
# That took 3.72 seconds.
# Getting data... 2
# That took 3.91 seconds.
# Getting data... 3
# That took 4.27 seconds.
# Getting data... 4
# That took 5.16 seconds.
# Getting data... 5
# That took 4.89 seconds.
# Getting data... 6
# That took 8.54 seconds.
# Getting data... 7
# That took 7.5 seconds.
# Getting data... 8
# That took 6.64 seconds.
# Getting data... 9
# That took 6.5 seconds.
# Getting data... 10
# That took 5.76 seconds.
# Getting data... 11
# That took 5.82 seconds.
# Getting data... 12
# That took 5.91 seconds.
# Getting data... 13
# That took 5.85 seconds.
# Getting data... 14
# That took 4.48 seconds.
# Getting data... 15
# That took 6.45 seconds.
# Getting data... 16
# That took 68.09 seconds.
# Getting data... 17
# That took 7.36 seconds.
# Getting data... 18
# That took 6.68 seconds.
# Getting data... 19
# That took 5.58 seconds.
# Getting data... 20
# That took 5.12 seconds.
# Getting data... 21
# That took 4.63 seconds.
# Getting data... 22
# That took 4.7 seconds.
# Getting data... 23
# That took 5.41 seconds.
# Final formatting...
# Done
# That all took 423.85 seconds.
# Chunk 4 of 4:
# Getting data... 0
# That took 4.93 seconds.
# Getting data... 1
# That took 3.78 seconds.
# Getting data... 2
# That took 3.03 seconds.
# Getting data... 3
# That took 3.59 seconds.
# Getting data... 4
# That took 4.19 seconds.
# Getting data... 5
# That took 5.66 seconds.
# Getting data... 6
# That took 8.12 seconds.
# Getting data... 7
# That took 6.09 seconds.
# Getting data... 8
# That took 7.95 seconds.
# Getting data... 9
# That took 7.67 seconds.
# Getting data... 10
# That took 6.43 seconds.
# Getting data... 11
# That took 8.98 seconds.
# Getting data... 12
# That took 6.05 seconds.
# Getting data... 13
# That took 6.48 seconds.
# Getting data... 14
# That took 6.33 seconds.
# Getting data... 15
# That took 6.74 seconds.
# Getting data... 16
# That took 7.08 seconds.
# Getting data... 17
# That took 8.49 seconds.
# Getting data... 18
# That took 10.89 seconds.
# Getting data... 19
# That took 6.85 seconds.
# Getting data... 20
# That took 5.03 seconds.
# Getting data... 21
# That took 4.68 seconds.
# Getting data... 22
# That took 5.44 seconds.
# Getting data... 23
# That took 16.13 seconds.
# Final formatting...
# Done
# That all took 163.89 seconds.
# Whole thing took 1176.24 seconds.

# %% [markdown]
# Dump data to json file. Here, the final output is 185 MB, and zips to 8 MB.

# %%
# testing sample routes scraping with tzinfo fix
with open('sample_routes_data_pst_15s.json', 'w') as outfile:
    json.dump(get_some_times(['1', '14'], hours = 24), outfile)
# Out:
# Getting data... 0
# That took 4.88 seconds.
# Getting data... 1
# That took 3.28 seconds.
# Getting data... 2
# That took 3.95 seconds.
# Getting data... 3
# That took 3.84 seconds.
# Getting data... 4
# That took 3.9 seconds.
# Getting data... 5
# That took 4.55 seconds.
# Getting data... 6
# That took 4.29 seconds.
# Getting data... 7
# That took 4.34 seconds.
# Getting data... 8
# That took 4.89 seconds.
# Getting data... 9
# That took 3.99 seconds.
# Getting data... 10
# That took 3.32 seconds.
# Getting data... 11
# That took 4.28 seconds.
# Getting data... 12
# That took 4.0 seconds.
# Getting data... 13
# That took 4.18 seconds.
# Getting data... 14
# That took 5.43 seconds.
# Getting data... 15
# That took 4.32 seconds.
# Getting data... 16
# That took 4.39 seconds.
# Getting data... 17
# That took 4.2 seconds.
# Getting data... 18
# That took 4.12 seconds.
# Getting data... 19
# That took 3.75 seconds.
# Getting data... 20
# That took 9.7 seconds.
# Getting data... 21
# That took 3.84 seconds.
# Getting data... 22
# That took 3.64 seconds.
# Getting data... 23
# That took 3.48 seconds.
# Final formatting...
# Done
# That all took 105.07 seconds.

# %%
with open ('routes24h20181015v2.json','w') as outfile:
    json.dump(allofem,outfile)
# Final output is 185 MB, zips to 8 MB.

# %%
# get a week's worth of data from route 14
daterange = [(2019, 1, 14 + i, 0) for i in range(7)]

result = []

for day in daterange:
    print(f"{datetime.now()}: Starting query for {datetime(*day)}.")
    result.extend(get_some_times(['14'], day, hours = 24))
# Out:
# 2019-02-27 19:30:18.818793: Starting query for 2019-01-14 00:00:00.
# Getting data... 0
# That took 3.99 seconds.
# Getting data... 1
# That took 2.53 seconds.
# Getting data... 2
# That took 3.63 seconds.
# Getting data... 3
# That took 3.56 seconds.
# Getting data... 4
# That took 3.88 seconds.
# Getting data... 5
# That took 3.51 seconds.
# Getting data... 6
# That took 4.69 seconds.
# Getting data... 7
# That took 5.2 seconds.
# Getting data... 8
# That took 5.7 seconds.
# Getting data... 9
# That took 7.45 seconds.
# Getting data... 10
# That took 5.22 seconds.
# Getting data... 11
# That took 5.08 seconds.
# Getting data... 12
# That took 4.96 seconds.
# Getting data... 13
# That took 5.21 seconds.
# Getting data... 14
# That took 6.18 seconds.
# Getting data... 15
# That took 4.9 seconds.
# Getting data... 16
# That took 6.05 seconds.
# Getting data... 17
# That took 5.57 seconds.
# Getting data... 18
# That took 5.2 seconds.
# Getting data... 19
# That took 3.05 seconds.
# Getting data... 20
# That took 4.33 seconds.
# Getting data... 21
# That took 4.45 seconds.
# Getting data... 22
# That took 9.45 seconds.
# Getting data... 23
# That took 4.41 seconds.
# Final formatting...
# Done
# That all took 118.85 seconds.
# 2019-02-27 19:32:17.670316: Starting query for 2019-01-15 00:00:00.
# Getting data... 0
# That took 2.61 seconds.
# Getting data... 1
# That took 4.46 seconds.
# Getting data... 2
# That took 1.85 seconds.
# Getting data... 3
# That took 3.73 seconds.
# Getting data... 4
# That took 4.06 seconds.
# Getting data... 5
# That took 4.37 seconds.
# Getting data... 6
# That took 4.99 seconds.
# Getting data... 7
# That took 5.44 seconds.
# Getting data... 8
# That took 8.94 seconds.
# Getting data... 9
# That took 5.73 seconds.
# Getting data... 10
# That took 5.15 seconds.
# Getting data... 11
# That took 5.01 seconds.
# Getting data... 12
# That took 5.26 seconds.
# Getting data... 13
# That took 5.0 seconds.
# Getting data... 14
# That took 5.54 seconds.
# Getting data... 15
# That took 5.96 seconds.
# Getting data... 16
# That took 5.75 seconds.
# Getting data... 17
# That took 5.38 seconds.
# Getting data... 18
# That took 5.36 seconds.
# Getting data... 19
# That took 4.96 seconds.
# Getting data... 20
# That took 4.44 seconds.
# Getting data... 21
# That took 7.08 seconds.
# Getting data... 22
# That took 3.0 seconds.
# Getting data... 23
# That took 4.38 seconds.
# Final formatting...
# Done
# That all took 119.05 seconds.
# 2019-02-27 19:34:16.719024: Starting query for 2019-01-16 00:00:00.
# Getting data... 0
# That took 4.61 seconds.
# Getting data... 1
# That took 3.52 seconds.
# Getting data... 2
# That took 2.78 seconds.
# Getting data... 3
# That took 3.73 seconds.
# Getting data... 4
# That took 3.57 seconds.
# Getting data... 5
# That took 4.45 seconds.
# Getting data... 6
# That took 5.11 seconds.
# Getting data... 7
# That took 5.38 seconds.
# Getting data... 8
# That took 6.39 seconds.
# Getting data... 9
# That took 5.78 seconds.
# Getting data... 10
# That took 5.43 seconds.
# Getting data... 11
# That took 5.2 seconds.
# Getting data... 12
# That took 5.16 seconds.
# Getting data... 13
# That took 4.41 seconds.
# Getting data... 14
# That took 5.29 seconds.
# Getting data... 15
# That took 5.31 seconds.
# Getting data... 16
# That took 5.63 seconds.
# Getting data... 17
# That took 17.22 seconds.
# Getting data... 18
# That took 5.19 seconds.
# Getting data... 19
# That took 4.99 seconds.
# Getting data... 20
# That took 4.3 seconds.
# Getting data... 21
# That took 4.09 seconds.
# Getting data... 22
# That took 4.18 seconds.
# Getting data... 23
# That took 3.92 seconds.
# Final formatting...
# Done
# That all took 126.38 seconds.
# 2019-02-27 19:36:23.103953: Starting query for 2019-01-17 00:00:00.
# Getting data... 0
# That took 3.73 seconds.
# Getting data... 1
# That took 4.26 seconds.
# Getting data... 2
# That took 3.78 seconds.
# Getting data... 3
# That took 3.59 seconds.
# Getting data... 4
# That took 3.75 seconds.
# Getting data... 5
# That took 4.31 seconds.
# Getting data... 6
# That took 5.12 seconds.
# Getting data... 7
# That took 5.65 seconds.
# Getting data... 8
# That took 6.13 seconds.
# Getting data... 9
# That took 6.83 seconds.
# Getting data... 10
# That took 5.15 seconds.
# Getting data... 11
# That took 5.36 seconds.
# Getting data... 12
# That took 5.51 seconds.
# Getting data... 13
# That took 5.01 seconds.
# Getting data... 14
# That took 3.34 seconds.
# Getting data... 15
# That took 5.43 seconds.
# Getting data... 16
# That took 5.45 seconds.
# Getting data... 17
# That took 5.33 seconds.
# Getting data... 18
# That took 15.64 seconds.
# Getting data... 19
# That took 4.66 seconds.
# Getting data... 20
# That took 4.33 seconds.
# Getting data... 21
# That took 2.98 seconds.
# Getting data... 22
# That took 4.08 seconds.
# Getting data... 23
# That took 3.91 seconds.
# Final formatting...
# Done
# That all took 123.93 seconds.
# 2019-02-27 19:38:27.036049: Starting query for 2019-01-18 00:00:00.
# Getting data... 0
# That took 3.73 seconds.
# Getting data... 1
# That took 3.61 seconds.
# Getting data... 2
# That took 3.55 seconds.
# Getting data... 3
# That took 3.65 seconds.
# Getting data... 4
# That took 3.69 seconds.
# Getting data... 5
# That took 4.16 seconds.
# Getting data... 6
# That took 4.65 seconds.
# Getting data... 7
# That took 5.3 seconds.
# Getting data... 8
# That took 3.8 seconds.
# Getting data... 9
# That took 5.41 seconds.
# Getting data... 10
# That took 5.15 seconds.
# Getting data... 11
# That took 4.91 seconds.
# Getting data... 12
# That took 5.13 seconds.
# Getting data... 13
# That took 4.02 seconds.
# Getting data... 14
# That took 5.0 seconds.
# Getting data... 15
# That took 5.33 seconds.
# Getting data... 16
# That took 3.63 seconds.
# Getting data... 17
# That took 5.43 seconds.
# Getting data... 18
# That took 5.28 seconds.
# Getting data... 19
# That took 4.65 seconds.
# Getting data... 20
# That took 4.19 seconds.
# Getting data... 21
# That took 4.1 seconds.
# Getting data... 22
# That took 2.52 seconds.
# Getting data... 23
# That took 3.94 seconds.
# Final formatting...
# Done
# That all took 105.22 seconds.
# 2019-02-27 19:40:12.260707: Starting query for 2019-01-19 00:00:00.
# Getting data... 0
# That took 3.95 seconds.
# Getting data... 1
# That took 2.63 seconds.
# Getting data... 2
# That took 3.46 seconds.
# Getting data... 3
# That took 3.81 seconds.
# Getting data... 4
# That took 3.94 seconds.
# Getting data... 5
# That took 3.9 seconds.
# Getting data... 6
# That took 3.93 seconds.
# Getting data... 7
# That took 4.13 seconds.
# Getting data... 8
# That took 4.41 seconds.
# Getting data... 9
# That took 4.53 seconds.
# Getting data... 10
# That took 4.86 seconds.
# Getting data... 11
# That took 4.62 seconds.
# Getting data... 12
# That took 4.63 seconds.
# Getting data... 13
# That took 4.7 seconds.
# Getting data... 14
# That took 4.39 seconds.
# Getting data... 15
# That took 3.94 seconds.
# Getting data... 16
# That took 4.49 seconds.
# Getting data... 17
# That took 4.76 seconds.
# Getting data... 18
# That took 4.43 seconds.
# Getting data... 19
# That took 4.41 seconds.
# Getting data... 20
# That took 4.02 seconds.
# Getting data... 21
# That took 5.03 seconds.
# Getting data... 22
# That took 4.43 seconds.
# Getting data... 23
# That took 3.83 seconds.
# Final formatting...
# Done
# That all took 101.59 seconds.
# 2019-02-27 19:41:53.856714: Starting query for 2019-01-20 00:00:00.
# Getting data... 0
# That took 5.78 seconds.
# Getting data... 1
# That took 2.46 seconds.
# Getting data... 2
# That took 3.95 seconds.
# Getting data... 3
# That took 5.33 seconds.
# Getting data... 4
# That took 3.54 seconds.
# Getting data... 5
# That took 3.89 seconds.
# Getting data... 6
# That took 4.06 seconds.
# Getting data... 7
# That took 4.28 seconds.
# Getting data... 8
# That took 4.6 seconds.
# Getting data... 9
# That took 4.53 seconds.
# Getting data... 10
# That took 4.7 seconds.
# Getting data... 11
# That took 4.51 seconds.
# Getting data... 12
# That took 10.67 seconds.
# Getting data... 13
# That took 4.96 seconds.
# Getting data... 14
# That took 4.65 seconds.
# Getting data... 15
# That took 4.84 seconds.
# Getting data... 16
# That took 3.04 seconds.
# Getting data... 17
# That took 4.74 seconds.
# Getting data... 18
# That took 4.48 seconds.
# Getting data... 19
# That took 4.53 seconds.
# Getting data... 20
# That took 4.45 seconds.
# Getting data... 21
# That took 2.31 seconds.
# Getting data... 22
# That took 4.11 seconds.
# Getting data... 23
# That took 2.74 seconds.
# Final formatting...
# Done
# That all took 107.41 seconds.

# %%
with open('route_14_week_data.json', 'w') as f:
    json.dump(result, f)
